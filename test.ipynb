# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

# %%
df_table = pd.read_json('dataset/visdial/coo_annotations/sample.json')

# %%
print(df_table.iloc[1]['dialog_full'])
# Out:
# Q:what shape is the sculpture
# A:it's not a sculpture, it's a science project, with forks wires and bananas
# Q:are there people
# A:no
# Q:is it inside
# A:yes
# Q:do you see windows
# A:no, it's taken in a lightbox
# Q:do you see furniture
# A:no
# Q:what color wall
# A:it's in a light box, it's all white
# Q:how many wires
# A:6
# Q:how many bananas
# A:2 whole, and 2 quartered
# Q:are the bananas yellow
# A:yes
# Q:are the forks silver
# A:yes

# %%
print(df_table.iloc[1]['supercategories'])
# Out:
# ['kitchen', 'food']

# %%
df_table.iloc[1]
# Out:
# image_id                                                      131565
# dialog             [{'answer': 128533, 'gt_index': 21, 'question'...
# caption            a sculpture has been created using forks and b...
# dialog_full        Q:what shape is the sculpture\nA:it's not a sc...
# supercategories                                      [kitchen, food]
# categories                                            [fork, banana]
# Name: 1, dtype: object

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 图像文件路径
image_path = 'dataset/visdial/sample/COCO_train2014_000000131565.jpg'

# 加载和显示图像
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # 不显示坐标轴
plt.show()

# %%
df_image = np.load('dataset/mmd/dev/dev_ims.npy', allow_pickle=True)

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import PIL

# %%
def show_image(image, title):
    plt.imshow(PIL.Image.fromarray(image))
    plt.title(title)
    plt.show()

# %%
df_table
# Out:
#                                                  dialog  replaced_idx  \
# 0     [hello , how are you tonight ?, i am tired . i...             4
# 1     [good morning how old are you i am 34, i am mu...             2
# 2     [hello , how are you this evening ?, hello how...             4
# 3     [hello , how are you this morning ?, not good ...            12
# 4     [hey how are you today ?, i am great . you hav...             3
# ...                                                 ...           ...
# 2396  [Hi . I can't get going on my computer until I...             5
# 2397  [Was there an accident on the freeway today ?,...             3
# 2398  [Would you please teach me how to use the comp...             3
# 2399  [How may I help you ?, There ’ s a problem wit...            10
# 2400  [Is there a swimming pool in this hotel ?, We ...             1
#
#       img_idx     score dialog_dataset    dialog_file img_dataset  \
# ...

# %%
df_table.iloc[15]['dialog']
# Out:
# ['organic food are good for health',
#  'i prefer italian . especially garlic bread .',
#  'in the fastest world all human are like shortcut to do work',
#  'that is interesting . what kind of sports do you play ? i like gymnastics .',
#  'its totally wrong its ending will be worst then ever',
#  'most likely . yes , what is your favorite color ?',
#  'i like boxing its all time favorite game to me',
#  'i won a gold metal in the olympics as a gymnast .',
#  'my favorite color is sky blue like ocean and sky',
#  'i really like the color yellow because it reminds me of flowers .',
#  'wow you are great dude',
#  'how often do you go to the gym ? i go four hours a day .',
#  'simple four times a week',
#  'that is cool . do you compete in any sporting events ?',
#  'no i like play video games only',
#  'i do not like to play video games . going outside is awesome .']

# %%
img_array_reshaped = np.transpose(df_image[15], (1, 2, 0))
plt.imshow(img_array_reshaped)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
