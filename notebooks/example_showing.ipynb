# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json 
import sys

# %%
current_dir = os.getcwd()
dataset_dir = os.path.join(os.path.dirname(current_dir), 'dataset')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_image(caption, image_path):
    img = mpimg.imread(image_path)
    plt.imshow(img)
    plt.axis('off') 
    plt.title(caption)
    plt.show()

# %% [markdown]
# ## Example Showing for QA OOD detection data

# %%
# Real annotation table for coco
df_table = pd.read_json(f'{dataset_dir}/qaood/sample.json')

# %%
df_table
# Out:
#       image_id                                             dialog  \
# 0       265744  [{'answer': 71412, 'gt_index': 0, 'question': ...
# 1       131565  [{'answer': 128533, 'gt_index': 21, 'question'...
# 2       403826  [{'answer': 100985, 'gt_index': 93, 'question'...
# 3       403677  [{'answer': 71412, 'gt_index': 90, 'question':...
# 4       181079  [{'answer': 107505, 'gt_index': 75, 'question'...
# ...        ...                                                ...
# 9910      6664  [{'answer': 208888, 'gt_index': 11, 'question'...
# 9911    403194  [{'answer': 74224, 'gt_index': 60, 'question':...
# 9912    214985  [{'answer': 129985, 'gt_index': 86, 'question'...
# 9913    297326  [{'answer': 130682, 'gt_index': 43, 'question'...
# 9914    506856  [{'answer': 220618, 'gt_index': 48, 'question'...
#
#                                                 caption  \
# 0     a person standing next to a fence with horses ...
# 1     a sculpture has been created using forks and b...
# 2     there is a male baseball pitcher throwing the ...
# 3              a women who is looking at her cell phone
# 4     a dog that is sitting on a table in front of a...
# ...                                                 ...
# 9910  a tennis player hitting a ball at the tennis c...
# 9911  a bed has a white cover and a desk has a lapto...
# 9912     a young man holding a smart phone in his hands
# 9913  a young child is sitting at a table with a cak...
# 9914  a bird standing on a dirt patch next to small ...
#
#                                             dialog_full  \
# 0     Q:is there only 1 person\nA:yes\nQ:how many ho...
# 1     Q:what shape is the sculpture\nA:it's not a sc...
# 2     Q:is anyone else in the image\nA:no, just the ...
# 3     Q:is it a color photo\nA:yes\nQ:is it daytime\...
# 4     Q:is it a large dog\nA:no, quite small\nQ:what...
# ...                                                 ...
# 9910  Q:what color is court\nA:green\nQ:are there an...
# 9911  Q:any curtains\nA:no\nQ:what color are walls\n...
# 9912  Q:what color is the phone\nA:maybe gray, it's ...
# 9913  Q:is it a boy or girl\nA:a boy\nQ:how old\nA:4...
# 9914  Q:what kind of bird is it\nA:roadrunner\nQ:wha...
#
#                                supercategories  \
# 0                    [animal, person, kitchen]
# 1                              [kitchen, food]
# 2                             [sports, person]
# 3              [electronic, person, accessory]
# 4           [animal, kitchen, food, furniture]
# ...                                        ...
# 9910                          [person, sports]
# 9911  [kitchen, furniture, electronic, indoor]
# 9912  [electronic, person, vehicle, accessory]
# 9913                            [person, food]
# 9914                                  [animal]
#
#                                             categories
# 0                                 [horse, person, cup]
# 1                                       [fork, banana]
# 2                [sports ball, person, baseball glove]
# 3                        [cell phone, person, handbag]
# 4                 [dog, cat, bowl, cake, dining table]
# ...                                                ...
# 9910                           [person, tennis racket]
# 9911  [bottle, bed, laptop, mouse, keyboard, book, tv]
# 9912                [cell phone, person, car, handbag]
# 9913                                    [person, cake]
# 9914                                            [bird]
#
# [9915 rows x 6 columns]

# %%
k = 2
print('Image ID:', df_table.iloc[k]['image_id'])
print('*'*50)
print(df_table.iloc[k]['dialog_full'])
print('*'*50)
print(df_table.iloc[k]['supercategories'])
print(df_table.iloc[k]['categories'])
print('*'*50)
plot_image(df_table.iloc[k]['caption'], 
           f"{dataset_dir}/qaood/sample/COCO_train2014_{df_table.iloc[k]['image_id']:0>12}.jpg")
# Out:
# Image ID: 403826
# **************************************************
# Q:is anyone else in the image
# A:no, just the main pitcher
# Q:about how old is he
# A:he appears to be late teens
# Q:is he wearing a uniform
# A:yes, he is
# Q:is he wearing a hat
# A:yes, he is wearing a hat as well
# Q:what color is his uniform
# A:the uniform is black and white with red also
# Q:is he holding the ball or did he throw it
# A:it has just been released
# Q:is he on a professional field
# A:i can't tell but i will say no, based on the trees
# Q:is there a crowd watching
# A:i can't see any crowds
# Q:does he look happy
# A:he looks like he is concentrating very hard on the pitch
# Q:what color is his hair
# A:it appears to be brown
#
# **************************************************
# ['sports', 'person']
# ['sports ball', 'person', 'baseball glove']
# **************************************************

# %% [markdown]
# ## Example Showing for Real OOD detection data

# %%
import PIL
def show_image(image, title):
    plt.imshow(PIL.Image.fromarray(image))
    plt.title(title)
    plt.show()

# %%
df_table = pd.read_json(f'{dataset_dir}/realood/sample.json')

# %%
k = 15
print('Image ID:', df_table.iloc[k]['image_id'])
print('*'*50)
count = 0 
for i in df_table.iloc[k]['dialog']:
    if count % 2 == 0:
        print('S1:', i)
    else:
        print('S2:', i)
    count += 1
print('*'*50)
print('Categories:', df_table.iloc[k]['categories'])
print('Super Categories:', df_table.iloc[k]['supercategories'])
print('Similarity:', df_table.iloc[k]['score'])
print('*'*50)
plot_image(f"Image: {df_table.iloc[k]['image_id']}",
              f"{dataset_dir}/realood/sample/{df_table.iloc[k]['image_id']}.jpg")
# Out:
# Image ID: 2000000379842
# **************************************************
# S1: organic food are good for health
# S2: i prefer italian . especially garlic bread .
# S1: in the fastest world all human are like shortcut to do work
# S2: that is interesting . what kind of sports do you play ? i like gymnastics .
# S1: its totally wrong its ending will be worst then ever
# S2: most likely . yes , what is your favorite color ?
# S1: i like boxing its all time favorite game to me
# S2: i won a gold metal in the olympics as a gymnast .
# S1: my favorite color is sky blue like ocean and sky
# S2: i really like the color yellow because it reminds me of flowers .
# S1: wow you are great dude
# S2: how often do you go to the gym ? i go four hours a day .
# S1: simple four times a week
# S2: that is cool . do you compete in any sporting events ?
# S1: no i like play video games only
# S2: i do not like to play video games . going outside is awesome .
# **************************************************
# Categories: ['remote', 'book']
# Super Categories: ['electronic', 'indoor']
# Similarity: 0.5935840299
# **************************************************

# %% [markdown]
# ## Example Showing for MELD data

# %%
import torch
import clip
from PIL import Image
# Load CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)
df_table = pd.read_csv(f'{dataset_dir}/meldood/sample/train_annotation.csv')

# %%
df_table['Sentiment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sentiment'>

# %%
k = 800
image_id = f'dia{df_table.iloc[k]['Dialogue_ID']}_utt{df_table.iloc[k]["Utterance_ID"]}.jpg'
print('Image ID:', image_id)
print('*'*50)
print('Emotions:', df_table.iloc[k]['Emotion'])
print('Utterance:', df_table.iloc[k]['Utterance'])

print('*'*50)
plot_image(f"Image: {image_id}",
              f"{dataset_dir}/meldood/sample/train_image/{image_id}")



# Define the image path and the text
image_path = f"{dataset_dir}/meldood/sample/train_image/{image_id}"
label = ['joy', 'neutral', 'sadness', 'anger', 'fear', 'disgust', 'surprise']

# Preprocess the image
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)

print('*'*50)
for emo in label:
    text = f"The speaker is expressing {emo}."
    # Tokenize the text
    text_tokens = clip.tokenize([text]).to(device)

    # Encode the image and the text
    with torch.no_grad():
        image_features = clip_model.encode_image(image)
        text_features = clip_model.encode_text(text_tokens)

    # Normalize the features
    image_features = image_features / image_features.norm(dim=-1, keepdim=True)
    text_features = text_features / text_features.norm(dim=-1, keepdim=True)

    # Calculate the cosine similarity
    cosine_similarity = torch.matmul(image_features, text_features.T)

    # Print the cosine similarity
    print(f"Cosine Similarity for {emo}:", cosine_similarity.item())
# Out:
# Image ID: dia81_utt9.jpg
# **************************************************
# Emotions: neutral
# Utterance: Well, he didn't tell me.
# **************************************************
# **************************************************
# Cosine Similarity for joy: 0.197509765625
# Cosine Similarity for neutral: 0.2010498046875
# Cosine Similarity for sadness: 0.200927734375
# Cosine Similarity for anger: 0.192138671875
# Cosine Similarity for fear: 0.1990966796875
# Cosine Similarity for disgust: 0.1956787109375
# Cosine Similarity for surprise: 0.200927734375
